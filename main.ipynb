# %% [markdown]
# # Import phase

# %%
#from pgm_reader import Reader
import pgm
import numpy as np
import matplotlib.pyplot as plt

# %%
#
f = 'archive/archive/s1/1.pgm'

img = pgm.read_pgm(f)
fig, axs = plt.subplots(1,1)
fig.set_size_inches(4,4)
axs.imshow(img, cmap='gray')
plt.axis('off')
plt.savefig('Latex/pictures/test_subject_1.pdf')

# %%
img.shape
# Out:
# (112, 92)
